# %% [markdown]
# <a href="https://colab.research.google.com/github/erickmamede/Process_Imagem/blob/main/Processamento_de_Imagem_Tarefa_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### CARLOS HENRIQUE ALMEIDA ROCHA
# Matrícula: 201906840013
# ### ERICK MAMEDE SILVA DA COSTA
# Matrícula: 201906840033

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
caminho = '/content/drive/My Drive/Colab Notebooks/Processamento de Imagem/'
arquivo = 'proyectosinttulo_evox.jpg'

img = cv.imread(caminho + arquivo)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x338 at 0x7FBD50A593C0>

# %%
img_YCrCb = cv.cvtColor(img, cv.COLOR_BGR2YCrCb)
#canal de luminância
cv2_imshow(img_YCrCb[:,:,0])
#canais de crominância
cv2_imshow(img_YCrCb[:,:,1])
cv2_imshow(img_YCrCb[:,:,2])
# Out:
# <PIL.Image.Image image mode=L size=600x338 at 0x7FBD2F192BC0>
# <PIL.Image.Image image mode=L size=600x338 at 0x7FBD2F1918A0>
# <PIL.Image.Image image mode=L size=600x338 at 0x7FBD2F192BC0>
